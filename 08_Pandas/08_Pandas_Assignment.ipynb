# %% [markdown]
# ## 08 Pandas Assignment
# Let's explore the power of Pandas!
# Documentation on installation here: https://pandas.pydata.org/docs/getting_started/index.html#installation
#
# Getting started here: https://pandas.pydata.org/docs/user_guide/10min.html

# %%
#Load the library from your local machine (hint: use Anaconda distribution or see documentation)

import pandas as pd

# %% [markdown]
# ### 1 (5 points) Create a Series
# Name it "My_First_Series" and have it hold your 5 favorite numbers

# %%
My_First_Series = pd.Series([15, 26, 5, 9, 2])

# %% [markdown]
# 5/5

# %% [markdown]
# ### 2 (5 points) Create a Dataframe
# Create a custom dataframe called "My_Favorite_Movies" that uses a dictionary and a list. For the key, include the name of your favorite 2 movies. For the pair (list) include your three favorite characters and the year the movie came out. Finally, set your index for characters and year of release.
# Hint: You should have two columns and four rows with row titles (index)

# %%
My_Favorite_Movies= pd.DataFrame({'The Departed': ['Billy', 'Colin','Costello', 2006],
              'Walter Sojak': ['Ricky Bobby', 'Cal Naughton Jr.', 'Jean Girard', 2006]}, 
              index=['Favorite characters', '2nd Favorite characters', '3rd Favorite characters', 'Release Year'])

# %%
My_Favorite_Movies
# Out:
#                         The Departed      Walter Sojak
# Favorite characters            Billy       Ricky Bobby
# 2nd Favorite characters        Colin  Cal Naughton Jr.
# 3rd Favorite characters     Costello       Jean Girard
# Release Year                    2006              2006

# %% [markdown]
# 5/5

# %% [markdown]
# ### 3 (5 points) Loading a Dataset
# Load the Titanic .csv file and return the last five rows using a Pandas method. (Data Dictionary can be found here: https://www.kaggle.com/c/titanic/data). Note the Titanic.csv file can be found on Moodle under Week 8 and in the Github folder.

# %%
passengers = pd.read_csv('/Users/liamhettinger/Documents/Panda/08_Pandas/titanic.csv')
passengers.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# 5/5

# %% [markdown]
# ### 4 (5 points) Exploring Your Dataset
# Let's see what our dataset looks like with some basic exploratory methods. Return the number of rows and columns, describe the data using your new favorite Pandas methods

# %%
passengers.shape
# Out:
# (891, 12)

# %%
passengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
pd.value_counts(passengers["Survived"]).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 5/5

# %% [markdown]
# ### 5 (5 points) Analyzing Your Dataset
# Using our .iloc method, calculate the average age of the first 400 passengers

# %%
Age_passengers_subset = passengers.iloc[0:400, 5]
pd.DataFrame.mean(Age_passengers_subset)
# Out:
# 28.68245341614907

# %% [markdown]
# ### 6 (5 points) Analyzing Your Dataset
# Create a Dataframe called Survivor_age that includes just the ages and fares using the .loc method.

# %%
#made the assumption that we only wanted passengers who survived

Survived_passengers = passengers[passengers["Survived"] == 1]

Survivor_age = ['Age', 'Fare']

Survivor_age = pd.DataFrame(Survived_passengers.loc[:, Survivor_age])

Survivor_age
# Out:
#       Age     Fare
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 8    27.0  11.1333
# 9    14.0  30.0708
# ..    ...      ...
# 875  15.0   7.2250
# 879  56.0  83.1583
# 880  25.0  26.0000
# 887  19.0  30.0000
# 889  26.0  30.0000
#
# [342 rows x 2 columns]

# %% [markdown]
# 5/5

# %% [markdown]
# ### 7 (15 points) Analyzing Your Dataset
# Create a new DataFrame called lower_survivors which include all 2nd and 3rd class passengers who survived and departed from Cherbourg. (Hint: you should see 34 survivors - verify this with your favorite Pandas method)

# %%
Survived_passengers_subset1 = passengers[(passengers["Pclass"] > 1) & (passengers["Survived"] == 1) & (passengers["Embarked"] == 'C')]

# %%
Survived_passengers_subset1.shape
# Out:
# (34, 12)

# %%
Survived_passengers_subset1
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 19            20         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 65            66         1       3
# 125          126         1       3
# 128          129         1       3
# 207          208         1       3
# 255          256         1       3
# 367          368         1       3
# 381          382         1       3
# 389          390         1       2
# 448          449         1       3
# 455          456         1       3
# 469          470         1       3
# 473          474         1       2
# 533          534         1       3
# 547          548         1       2
# 553          554         1       3
# 608          609         1       2
# 622          623         1       3
# 644          645         1       3
# 691          692         1       3
# 709          710         1       3
# 762          763         1       3
# 780          781         1       3
# 803          804         1       3
# 827          828         1       2
# 830          831         1       3
# 858          859         1       3
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
#
#                                                   Name     Sex    Age  SibSp  \
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.00      1
# 19                             Masselmani, Mrs. Fatima  female    NaN      0
# 36                                    Mamee, Mr. Hanna    male    NaN      0
# 39                         Nicola-Yarred, Miss. Jamila  female  14.00      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.00      1
# 65                            Moubarek, Master. Gerios    male    NaN      1
# 125                       Nicola-Yarred, Master. Elias    male  12.00      1
# 128                                  Peter, Miss. Anna  female    NaN      1
# 207                        Albimona, Mr. Nassef Cassem    male  26.00      0
# 255            Touma, Mrs. Darwis (Hanne Youssef Razi)  female  29.00      0
# 367                     Moussa, Mrs. (Mantoura Boulos)  female    NaN      0
# 381                        Nakid, Miss. Maria ("Mary")  female   1.00      0
# 389                              Lehmann, Miss. Bertha  female  17.00      0
# 448                     Baclini, Miss. Marie Catherine  female   5.00      2
# 455                                 Jalsevac, Mr. Ivan    male  29.00      0
# 469                      Baclini, Miss. Helene Barbara  female   0.75      2
# 473       Jerwan, Mrs. Amin S (Marie Marthe Thuillard)  female  23.00      0
# 533             Peter, Mrs. Catherine (Catherine Rizk)  female    NaN      0
# 547                         Padro y Manent, Mr. Julian    male    NaN      0
# 553                  Leeni, Mr. Fahim ("Philip Zenni")    male  22.00      0
# 608  Laroche, Mrs. Joseph (Juliette Marie Louise La...  female  22.00      1
# 622                                   Nakid, Mr. Sahid    male  20.00      1
# 644                             Baclini, Miss. Eugenie  female   0.75      2
# 691                                 Karun, Miss. Manca  female   4.00      0
# 709  Moubarek, Master. Halim Gonios ("William George")    male    NaN      1
# 762                              Barah, Mr. Hanna Assi    male  20.00      0
# 780                               Ayoub, Miss. Banoura  female  13.00      0
# 803                    Thomas, Master. Assad Alexander    male   0.42      0
# 827                              Mallet, Master. Andre    male   1.00      0
# 830            Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.00      1
# 858              Baclini, Mrs. Solomon (Latifa Qurban)  female  24.00      0
# 866                       Duran y More, Miss. Asuncion  female  27.00      1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.00      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.00      0
#
#      Parch           Ticket     Fare  Cabin Embarked
# 9        0           237736  30.0708    NaN        C
# 19       0             2649   7.2250    NaN        C
# 36       0             2677   7.2292    NaN        C
# 39       0             2651  11.2417    NaN        C
# 43       2    SC/Paris 2123  41.5792    NaN        C
# 65       1             2661  15.2458    NaN        C
# 125      0             2651  11.2417    NaN        C
# 128      1             2668  22.3583  F E69        C
# 207      0             2699  18.7875    NaN        C
# 255      2             2650  15.2458    NaN        C
# 367      0             2626   7.2292    NaN        C
# 381      2             2653  15.7417    NaN        C
# 389      0          SC 1748  12.0000    NaN        C
# 448      1             2666  19.2583    NaN        C
# 455      0           349240   7.8958    NaN        C
# 469      1             2666  19.2583    NaN        C
# 473      0  SC/AH Basle 541  13.7917      D        C
# 533      2             2668  22.3583    NaN        C
# 547      0    SC/PARIS 2146  13.8625    NaN        C
# 553      0             2620   7.2250    NaN        C
# 608      2    SC/Paris 2123  41.5792    NaN        C
# 622      1             2653  15.7417    NaN        C
# 644      1             2666  19.2583    NaN        C
# 691      1           349256  13.4167    NaN        C
# 709      1             2661  15.2458    NaN        C
# 762      0             2663   7.2292    NaN        C
# 780      0             2687   7.2292    NaN        C
# 803      1             2625   8.5167    NaN        C
# 827      2  S.C./PARIS 2079  37.0042    NaN        C
# 830      0             2659  14.4542    NaN        C
# 858      3             2666  19.2583    NaN        C
# 866      0    SC/PARIS 2149  13.8583    NaN        C
# 874      0        P/PP 3381  24.0000    NaN        C
# 875      0             2667   7.2250    NaN        C

# %% [markdown]
# 15/15

# %% [markdown]
# ### 8 (15 points)  Analyzing Your Dataset
# Using the groupby method, let's see the count survival rates for those over 55 by Sex and Class

# %%
passengers[passengers['Age']>55].groupby(['Sex', 'Pclass'])["Survived"].mean()
# Out:
# Sex     Pclass
# female  1         1.000000
#         2         0.000000
#         3         1.000000
# male    1         0.157895
#         2         0.166667
#         3         0.000000
# Name: Survived, dtype: float64

# %% [markdown]
# 15/15

# %% [markdown]
# ### 9 (15 points) Lambda Functions
# As we saw, lambda functions are handy bite size functions that can be inserted inline or called from existing custom functions. One of the best uses with Pandas is for encoding data.
#
# Let's write a function to encode the ports passengers embarked from into their full names and create a new column to hold this data. (C = Cherbourg, Q = Queenstown, S = Southampton)

# %%
def embarked(x):
    if x['Embarked'] == 'C':
        return "Cherbourg"
    elif x['Embarked'] == 'Q':
        return "Queenstown"
    else:
        return "Southampton"


passengers['Full Name Embarked'] = passengers.apply(lambda x: embarked(x), axis=1)

# %%
passengers
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Full Name Embarked
# 0        0         A/5 21171   7.2500   NaN        S        Southampton
# 1        0          PC 17599  71.2833   C85        C          Cherbourg
# 2        0  STON/O2. 3101282   7.9250   NaN        S        Southampton
# 3        0            113803  53.1000  C123        S        Southampton
# 4        0            373450   8.0500   NaN        S        Southampton
# ..     ...               ...      ...   ...      ...                ...
# 886      0            211536  13.0000   NaN        S        Southampton
# 887      0            112053  30.0000   B42        S        Southampton
# 888      2        W./C. 6607  23.4500   NaN        S        Southampton
# 889      0            111369  30.0000  C148        C          Cherbourg
# 890      0            370376   7.7500   NaN        Q         Queenstown
#
# [891 rows x 13 columns]

# %% [markdown]
# 15/15

# %% [markdown]
# ### (25 points) Making Data from Data
# Let's say we want to look at the cost of a ticket today and compute a senior citizen of 30% off for those over 45 (hey, it was 1912!) and departing from Southampton.
#
# 1. Create a DataFrame called senior_citizen that holds the conditionals mentioned above
# 2. Write a lambda function to apply a 30% discount to each Fare row and create a new column caled "Discount"
# 3. Compute the mean for this new "Discount" column (Hint: should come in at ~24.34)
# 4. Plot the Discount column (Hint: use the handy pd.value_counts operator)

# %%
senior_citizen = pd.DataFrame(passengers.loc[(passengers['Age'] > 45) & (passengers['Embarked'] == 'S')])
senior_citizen
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 92            93         0       1
# ..           ...       ...     ...
# 851          852         0       3
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 873          874         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 92                         Chaffee, Mr. Herbert Fuller    male  46.0      1
# ..                                                 ...     ...   ...    ...
# 851                                Svensson, Mr. Johan    male  74.0      0
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
#
#      Parch       Ticket     Fare Cabin Embarked Full Name Embarked  Discount
# 6        0        17463  51.8625   E46        S        Southampton  36.30375
# 11       0       113783  26.5500  C103        S        Southampton  18.58500
# 15       0       248706  16.0000   NaN        S        Southampton  11.20000
# 33       0   C.A. 24579  10.5000   NaN        S        Southampton   7.35000
# 92       0  W.E.P. 5734  61.1750   E31        S        Southampton  42.82250
# ..     ...          ...      ...   ...      ...                ...       ...
# 851      0       347060   7.7750   NaN        S        Southampton   5.44250
# 857      0       113055  26.5500   E17        S        Southampton  18.58500
# 862      0        17466  25.9292   D17        S        Southampton  18.15044
# 871      1        11751  52.5542   D35        S        Southampton  36.78794
# 873      0       345765   9.0000   NaN        S        Southampton   6.30000
#
# [73 rows x 14 columns]

# %%
def discount(x):
    if x['Age'] > 45:
        return x['Fare'] * .70
    else:
        return x['Fare']

senior_citizen['Discount'] = senior_citizen.apply(lambda x: discount(x), axis=1)
senior_citizen
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 92            93         0       1
# ..           ...       ...     ...
# 851          852         0       3
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 873          874         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 92                         Chaffee, Mr. Herbert Fuller    male  46.0      1
# ..                                                 ...     ...   ...    ...
# 851                                Svensson, Mr. Johan    male  74.0      0
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
#
#      Parch       Ticket     Fare Cabin Embarked Full Name Embarked  Discount
# 6        0        17463  51.8625   E46        S        Southampton  36.30375
# 11       0       113783  26.5500  C103        S        Southampton  18.58500
# 15       0       248706  16.0000   NaN        S        Southampton  11.20000
# 33       0   C.A. 24579  10.5000   NaN        S        Southampton   7.35000
# 92       0  W.E.P. 5734  61.1750   E31        S        Southampton  42.82250
# ..     ...          ...      ...   ...      ...                ...       ...
# 851      0       347060   7.7750   NaN        S        Southampton   5.44250
# 857      0       113055  26.5500   E17        S        Southampton  18.58500
# 862      0        17466  25.9292   D17        S        Southampton  18.15044
# 871      1        11751  52.5542   D35        S        Southampton  36.78794
# 873      0       345765   9.0000   NaN        S        Southampton   6.30000
#
# [73 rows x 14 columns]

# %%
senior_citizen['Discount'].mean()
# Out:
# 24.341142191780822

# %%
passengers.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked Full Name Embarked  \
# 0       0         A/5 21171   7.2500   NaN        S        Southampton
# 1       0          PC 17599  71.2833   C85        C          Cherbourg
# 2       0  STON/O2. 3101282   7.9250   NaN        S        Southampton
# 3       0            113803  53.1000  C123        S        Southampton
# 4       0            373450   8.0500   NaN        S        Southampton
# 5       0            330877   8.4583   NaN        Q         Queenstown
# 6       0             17463  51.8625   E46        S        Southampton
# 7       1            349909  21.0750   NaN        S        Southampton
# 8       2            347742  11.1333   NaN        S        Southampton
# 9       0            237736  30.0708   NaN        C          Cherbourg
# 10      1           PP 9549  16.7000    G6        S        Southampton
# 11      0            113783  26.5500  C103        S        Southampton
# 12      0         A/5. 2151   8.0500   NaN        S        Southampton
# 13      5            347082  31.2750   NaN        S        Southampton
# 14      0            350406   7.8542   NaN        S        Southampton
# 15      0            248706  16.0000   NaN        S        Southampton
# 16      1            382652  29.1250   NaN        Q         Queenstown
# 17      0            244373  13.0000   NaN        S        Southampton
# 18      0            345763  18.0000   NaN        S        Southampton
# 19      0              2649   7.2250   NaN        C          Cherbourg
#
#    Discount
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None

# %%
pd.value_counts(senior_citizen['Discount']).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 25/25
